# %% [markdown]
# <a href="https://colab.research.google.com/github/Dave5918/Kaggle/blob/main/deepFraudetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import pandas as pd
data=pd.read_csv("creditcard.csv")
data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 47623  43281 -0.696585  1.108944  1.413769 -0.127104  0.018555 -0.455078
# 47624  43282 -0.282262 -1.212401  2.174897 -0.181501 -1.604027 -0.332694
# 47625  43282 -1.513495 -0.206282 -0.702405  1.056423  1.058711 -0.708973
# 47626  43282 -0.659193  1.270953  0.946464 -0.370180  1.619207 -0.288297
# 47627  43282  1.121749 -0.208202  0.660816  0.857988 -0.823614 -0.422509
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
# Drop rows with NaN values from both input and output
cleaned_data = data.dropna()
input = cleaned_data.iloc[:, :-1]
output = cleaned_data.iloc[:, -1]

# Convert to TensorFlow Tensors
input_tensor = tf.convert_to_tensor(input, dtype=tf.float32)
output_tensor = tf.convert_to_tensor(output, dtype=tf.int32)

print("Input shape:", input_tensor.shape)
print("Output shape:", output_tensor.shape)
# Out:
# Input shape: (47627, 30)
# Output shape: (47627,)

# %%
input_layer = keras.Input(shape=(input_tensor.shape[1],))
dense_layer = keras.layers.Dense(64, activation='relu')(input_layer)
output_layer = keras.layers.Dense(1, activation='sigmoid')(dense_layer)

model = keras.Model(inputs=input_layer, outputs=output_layer)

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=["accuracy"]
)

model.fit(
    input_tensor,
    output_tensor,
    epochs=10
)
# Out:
# Epoch 1/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9319 - loss: 188.5281
# Epoch 2/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9950 - loss: 2.5425
# Epoch 3/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9949 - loss: 1.0455
# Epoch 4/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9947 - loss: 2.5034
# Epoch 5/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9956 - loss: 1.2790
# Epoch 6/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9955 - loss: 2.2337
# Epoch 7/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9954 - loss: 3.0341
# Epoch 8/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9959 - loss: 2.2782
# Epoch 9/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9959 - loss: 2.3635
# Epoch 10/10
# 1489/1489 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9966 - loss: 1.2610
